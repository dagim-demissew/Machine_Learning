# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd 
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Loading the data in a csv file into a data frame

# %%
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/iris.csv"

df = pd.read_csv(URL)
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 11             4.8           3.4            1.6           0.2     Iris-setosa
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 113            5.7           2.5            5.0           2.0  Iris-virginica
# 15             5.7           4.4            1.5           0.4     Iris-setosa
# 33             5.5           4.2            1.4           0.2     Iris-setosa

# %%
#lets see the shape of the 
df.shape
# Out:
# (150, 5)

# %%
df.Species.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Species'>

# %% [markdown]
# Our target column is what the model will assign to new values, viz to classify them. In our case the species column

# %%
target = df['Species']
features = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]

# %% [markdown]
# Now we build and train our classifier

# %%
classifier = LogisticRegression()
classifier.fit(features, target)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
classifier.score(features, target)
# Out:
# 0.9733333333333334

# %% [markdown]
# Make predictions. Let us predict the species of a flower with SepalLengthCm = 5.4, SepalWidthCm = 2.6, PetalLengthCm = 4.1, PetalWidthCm = 1.3

# %%
classifier.predict([[5.4,2.6,4.1,1.3]])
# Out:
# c:\Users\dagim\miniconda3\envs\ml_lab\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)
